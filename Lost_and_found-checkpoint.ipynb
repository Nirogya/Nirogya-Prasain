# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
df=pd.read_csv('data.csv')

# %%
df['text'] = df['item_name'] + " " + df['description']

# %%
X = df['text']
y = df['station_name']

# %%
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# %%
X_train = X_train.fillna("")
X_test = X_test.fillna("")

# %%
history = model.fit(X_train, y_train, epochs=50, batch_size=8,
                    validation_data=(X_test, y_test), verbose=0)

# %%
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.show()

# %%
predictions = model.predict(X_test)
predictions_rescaled = scaler.inverse_transform(predictions)
y_test_rescaled = scaler.inverse_transform(y_test)
# Out:
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step

# %%
for i, col in enumerate(numeric_cols):
    plt.figure()
    plt.plot(y_test_rescaled[:, i], label=f'Actual {col}')
    plt.plot(predictions_rescaled[:, i], label=f'Predicted {col}')
    plt.legend()
    plt.show()

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

print("MSE:", mse)
print("RMSE:", rmse)
# Out:
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# MSE: 3.053155231681151e-08
# RMSE: 0.000174732802635371

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(y_test, y_pred)
print("MAE:", mae)
# Out:
# MAE: 5.034910672281235e-05

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_pred)
print("R² Score:", r2)
# Out:
# R² Score: 0.006543980845352126

# %%
import matplotlib.pyplot as plt

plt.plot(y_test, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.legend()
plt.show()

# %%
from sklearn.metrics import r2_score
import numpy as np

# Predict using your trained model
y_pred = model.predict(X_test)

# Calculate R² score (how well predictions match actual values)
r2 = r2_score(y_test, y_pred)

# Convert R² to percentage form for "accuracy" display
accuracy_percentage = r2 * 100

print(f"Average Prediction Accuracy: {accuracy_percentage:.2f}%")
# Out:
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Average Prediction Accuracy: 0.65%

# %%
# Example for classification-like accuracy
predicted_classes = np.round(y_pred)  # or np.argmax(y_pred, axis=1) for multi-class
accuracy_percentage = (predicted_classes == y_test).mean() * 100

print(f"Average Prediction Accuracy: {accuracy_percentage:.2f}%")
# Out:
# Average Prediction Accuracy: 97.96%
